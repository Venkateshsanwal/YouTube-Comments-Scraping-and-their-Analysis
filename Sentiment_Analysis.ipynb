# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkateshsanwal/YouTube-Comments-Scraping-and-their-Analysis/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium
# !apt-get update # To update linux packages
# !apt install -y chromium-chromedriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

driver = webdriver.Chrome(options=options)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 45.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.2/460.2 kB 43.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.0 MB/s eta 0:00:00
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [50.4 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,074 kB]
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import csv

# Set up Chrome WebDriver with headless options
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=options)

# Navigate to the YouTube video URL
video_url = "https://www.youtube.com/watch?v=r7Y6S4-V1nw"
driver.get(video_url)

# Scroll down the page to load comments (you may adjust the number of scrolls)
for _ in range(50):
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(2)

# Scrape comments
comments = []

comment_elements = driver.find_elements(By.CSS_SELECTOR, "yt-formatted-string#content-text")
for comment_element in comment_elements:
    comments.append(comment_element.text)

# Write comments to a CSV file
csv_file = 'youtube_comments.csv'

with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Comment'])
    for comment in comments:
        writer.writerow([comment])

# Close the WebDriver
driver.quit()

# %%
import pandas as pd
import numpy as np
data=pd.read_csv("youtube_comments.csv")
data.head()
# Out:
#                                              Comment
# 0  Please call this man again to the show. He's a...
# 1  Ranveer is simultaneously scaring the shit out...
# 2  bring this guy back on your show its better th...
# 3  This podcast is better than last 50 series+mov...
# 4  This is one of the very few episodes where the...

# %%
data.shape
# Out:
# (940, 1)

# %%
import pandas as pd
import numpy as np
data=pd.read_csv("youtube_comments.csv")
data.head()
# Out:
#                                              Comment
# 0  Please call this man again to the show. He's a...
# 1  Ranveer is simultaneously scaring the shit out...
# 2  bring this guy back on your show its better th...
# 3  This podcast is better than last 50 series+mov...
# 4  This is one of the very few episodes where the...

# %%
pip install transformers

# %%
from transformers import pipeline
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="cardiffnlp/twitter-roberta-base-sentiment-latest")
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
pol=[] # list which will contain the polarity of the comments
for i in data.Comment:
    try:
        analysis =pipe(i)
        pol.append(analysis[0]['label'])

    except:
        pol.append(0)

# %%
data['sentiment']=pol

# %%
data
# Out:
#                                                Comment sentiment
# 0    Please call this man again to the show. He's a...  positive
# 1    Ranveer is simultaneously scaring the shit out...  negative
# 2    bring this guy back on your show its better th...  positive
# 3    This podcast is better than last 50 series+mov...  positive
# 4    This is one of the very few episodes where the...  positive
# ..                                                 ...       ...
# 935     Pls can i get the contact number of sarbajeet?   neutral
# 936  Does this man have any YouTube channel where h...  negative
# 937                   Can I get that psychic's no ????   neutral
# 938                                    The conjuring     neutral
# 939                     Where did the man (9ft) go ???   neutral
#
# [940 rows x 2 columns]

# %%
from transformers import pipeline
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="cardiffnlp/twitter-roberta-base-sentiment-latest")
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 21.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 21.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 53.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 1.03s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %%
# %%writefile app.py
from transformers import pipeline
import csv
import time
import streamlit as st
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

pipe = pipeline("text-classification", model="cardiffnlp/twitter-roberta-base-sentiment-latest")

# Function to scrape comments from a YouTube video
def scrape_comments(video_url):
    # Set up Chrome WebDriver with headless options
  dynamic=st.empty()
  dynamic.write("Scraping comments ...")

  options = webdriver.ChromeOptions()
  options.add_argument('--headless')
  options.add_argument('--no-sandbox')
  options.add_argument('--disable-dev-shm-usage')
  driver = webdriver.Chrome(options=options)

  # Navigate to the YouTube video URL
  url = video_url
  driver.get(url)

  # Scroll down the page to load comments (you may adjust the number of scrolls)
  for _ in range(50):
      driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
      time.sleep(2)

  # Scrape comments
  comments = []

  comment_elements = driver.find_elements(By.CSS_SELECTOR, "yt-formatted-string#content-text")
  for comment_element in comment_elements:
      comments.append(comment_element.text)

  # Write comments to a CSV file
  csv_file = 'youtube_comments.csv'

  with open(csv_file, 'w', newline='') as file:
      writer = csv.writer(file)
      writer.writerow(['Comment'])
      for comment in comments:
          writer.writerow([comment])

  # Close the WebDriver
  driver.quit()
  data=pd.read_csv("youtube_comments.csv")
  dynamic.empty()
  return data

# Function to analyze sentiment using TextBlob
def analyze_sentiment(data):
    pol=[]
    for i in data.Comment:
        if len(i)>500:
          i=i[:500]
        analysis =pipe(i)
        pol.append(analysis[0]['label'])
    return pol
# Create a Streamlit app
st.title("YouTube Comment Analysis")
dynamic=st.empty()
video_url = st.text_input("Enter the YouTube video URL:")
if st.button("Scrape Comments and Analyze Sentiment"):
    #pipe = pipeline("text-classification", model="cardiffnlp/twitter-roberta-base-sentiment-latest")

    comments = scrape_comments(video_url)

    st.write(f"Total comments scraped: {comments.shape[0]}")

    comment_analysis=analyze_sentiment(comments)

    st.write("Sentiment Analysis:")
    comments['Sentiment'] = comment_analysis
    st.write(comments["Sentiment"].value_counts())
    if st.button("Positive comments"):
      st.write(comments[comments[Sentiment=='positive']])
    if st.button("Negative comments"):
      st.write(comments[comments[Sentiment=='negative']])
    if st.button("Neutral comments"):
      st.write(comments[comments[Sentiment=='neutral']])
st.write("This app allows you to scrape comments from a YouTube video, analyze their sentiment, and view comments by category.")
# Out:
# Overwriting app.py

# %%
# %%writefile app.py
from transformers import pipeline
import csv
import time
import streamlit as st
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

pipe = pipeline("text-classification", model="cardiffnlp/twitter-roberta-base-sentiment-latest")

# Function to scrape comments from a YouTube video
def scrape_comments(video_url):
    # Set up Chrome WebDriver with headless options
    dynamic = st.empty()""
    dynamic.write("Scraping comments ...")

    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(options=options)

    # Navigate to the YouTube video URL
    url = video_url
    driver.get(url)

    # Scroll down the page to load comments (you may adjust the number of scrolls)
    for _ in range(50):
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(2)

    # Scrape comments
    comments = []

    comment_elements = driver.find_elements(By.CSS_SELECTOR, "yt-formatted-string#content-text")
    for comment_element in comment_elements:
        comments.append(comment_element.text)

    # Write comments to a CSV file
    csv_file = 'youtube_comments.csv'

    with open(csv_file, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Comment'])
        for comment in comments:
            writer.writerow([comment])

    # Close the WebDriver
    driver.quit()
    data = pd.read_csv("youtube_comments.csv")
    dynamic.empty()
    return data

# Function to analyze sentiment using TextBlob
def analyze_sentiment(data):
    pol = []
    for i in data.Comment:
        if len(i) > 500:
            i = i[:500]
        analysis = pipe(i)
        pol.append(analysis[0]['label'])
    return pol

# Create a Streamlit app
st.title("YouTube Comment Analysis")
dynamic = st.empty()
video_url = st.text_input("Enter the YouTube video URL:")
if st.button("Scrape Comments and Analyze Sentiment"):
    comments = scrape_comments(video_url)

    st.write(f"Total comments scraped: {comments.shape[0]}")

    comment_analysis = analyze_sentiment(comments)

    st.write("Sentiment Analysis:")
    comments['Sentiment'] = comment_analysis
    sentiment_counts = comments["Sentiment"].value_counts()
    st.write(sentiment_counts)

    if st.button("Positive comments"):
        st.write(comments[comments['Sentiment'] == 'positive'])

    if st.button("Negative comments"):
        st.write(comments[comments['Sentiment'] == 'negative'])

    if st.button("Neutral comments"):
        st.write(comments[comments['Sentiment'] == 'neutral'])

st.write("This app allows you to scrape comments from a YouTube video, analyze their sentiment, and view comments by category.")
# Out:
# Writing app.py

# %%
# %%writefile app.py
from transformers import pipeline
import csv
import time
import streamlit as st
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

pipe = pipeline("text-classification", model="cardiffnlp/twitter-roberta-base-sentiment-latest")

# Function to scrape comments from a YouTube video
def scrape_comments(video_url):
    # Set up Chrome WebDriver with headless options
    dynamic = st.empty()
    dynamic.write("Scraping comments ...")

    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(options=options)

    # Navigate to the YouTube video URL
    url = video_url
    driver.get(url)

    # Scroll down the page to load comments (you may adjust the number of scrolls)
    for _ in range(50):
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(2)

    # Scrape comments
    comments = []

    comment_elements = driver.find_elements(By.CSS_SELECTOR, "yt-formatted-string#content-text")
    for comment_element in comment_elements:
        comments.append(comment_element.text)

    # Write comments to a CSV file
    csv_file = 'youtube_comments.csv'

    with open(csv_file, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Comment'])
        for comment in comments:
            writer.writerow([comment])

    # Close the WebDriver
    driver.quit()
    data = pd.read_csv("youtube_comments.csv")
    dynamic.empty()
    return data

# Function to analyze sentiment using TextBlob
def analyze_sentiment(data):
    pol = []
    for i in data.Comment:
        if len(i) > 500:
            i = i[:500]
        analysis = pipe(i)
        pol.append(analysis[0]['label'])
    return pol

# Create a Streamlit app
st.title("YouTube Comment Analysis")
dynamic = st.empty()
video_url = st.text_input("Enter the YouTube video URL:")
if st.button("Scrape Comments and Analyze Sentiment"):
    comments = scrape_comments(video_url)

    st.write(f"Total comments scraped: {comments.shape[0]}")

    comment_analysis = analyze_sentiment(comments)

    st.write("Sentiment Analysis:")
    comments['Sentiment'] = comment_analysis
    sentiment_counts = comments["Sentiment"].value_counts()
    st.write(sentiment_counts)

    if st.button("Positive comments"):
        st.write(comments[comments['Sentiment'] == 'positive'])

    if st.button("Negative comments"):
        st.write(comments[comments['Sentiment'] == 'negative'])

    if st.button("Neutral comments"):
        st.write(comments[comments['Sentiment'] == 'neutral'])

st.write("This app allows you to scrape comments from a YouTube video, analyze their sentiment, and view comments by category.")

# %%
# !streamlit run app.py &>/content/logs.txt & npx localtunnel  - -port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.243.155.179
# npx: installed 22 in 6.056s
# Usage: lt --port [num] <options>
#
# Options:
#   -p, --port                Internal HTTP server port                 [required]
#   -h, --host                Upstream server providing forwarding
#                                              [default: "https://localtunnel.me"]
#   -s, --subdomain           Request this subdomain
#   -l, --local-host          Tunnel traffic to this host instead of localhost,
#                             override Host header to this host
#       --local-https         Tunnel traffic to a local HTTPS server     [boolean]
#       --local-cert          Path to certificate PEM file for local HTTPS server
#       --local-key           Path to certificate key file for local HTTPS server
#       --local-ca            Path to certificate authority file for self-signed
#                             certificates
#       --allow-invalid-cert  Disable certificate checks for your local HTTPS
# ...

# %%
pip install streamlit pandas transformers selenium

# %%
# !streamlit run app.py --server.port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.243.155.179:8501

# %%
# !npx localtunnel --port 8501
# Out:
# ^C
